# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `C:\Users\Merama.LAPTOP-8168G5BK\Desktop\BootCamp\Challenges\Module-12-Challenge\Starter_Code\Resources> C:\mongoimport.exe --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurios', 'classDB', 'config', 'local', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6443670612dee6403fbe1277'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
# ...

# %%
# assign the collection to a variable
establishment_list = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant ={ "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True}
    

#establishment_list.insert_one(new_restaurant)

# %%
# Insert the new restaurant into the collection

establishment_list.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
establishment_list.find_one({'BusinessName':'Penang Flavours'})
# Out:
# {'_id': ObjectId('64436d4f4ebc4332c70c8258'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields

query = {'BusinessType': 'Restaurant/Cafe/Canteen'}

#fields = {'BusinessTypeID': 1, 'BusinessType': 1}
fields = ['BusinessTypeID', 'BusinessType']

results = establishment_list.find(query, fields)

for result in results:
    pprint(result)
    
    
#query_new_rest = {'BusinessType': 'Restaurant/Cafe/Canteen'}
#fields = ['BusinessTypeID', 'BusinessType']

#establish.find_one(query_new_rest, fields)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6443670612dee6403fbe1277')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6443670612dee6403fbe1278')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6443670612dee6403fbe1279')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6443670612dee6403fbe127b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6443670612dee6403fbe127d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6443670612dee6403fbe127e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6443670612dee6403fbe1284')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6443670612dee6403fbe1285')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
query = {"BusinessName":"Penang Flavours"}
new_value = {"$set": {"BusinessTypeID":1}}
establishment_list.update_one(query, new_value)

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName":"Penang Flavours"}
results = establishment_list.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64436d4f4ebc4332c70c8258'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
# ...

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"

query = {'LocalAuthorityName': "Dover"}
fields = {'LocalAuthorityName': 1}
results = establishment_list.find(query,fields)
for result in results:
    pprint(result)
# Out:
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe1277')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe1278')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe1279')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe127a')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe127b')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe127c')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe127d')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe127e')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe127f')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe1280')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe1281')}
# {'LocalAuthorityName': 'Dover', '_id': ObjectId('6443670612dee6403fbe1282')}
# ...

# %%
establishment_list.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"

query = {'LocalAuthorityName': 'Dover'}
establishment_list.delete_many(query)


#results = establishment_list.find(query)
#for result in results:
#    print(result)

# %%
# Check if any remaining documents include Dover
establishment_list.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishment_list.find_one({})
# Out:
# {'_id': ObjectId('6443670612dee6403fbe155b'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': '4',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.196408', 'latitude': '51.086058'},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
# ...

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude

establishment_list.update_many(
                                {},
                               [{'$set':{'geocode.longitude': {'$toDouble':'$geocode.longitude' }}} ])

# %%
# Change the data type from String to Decimal for latitude
establishment_list.update_many(
                                {},
                               [{'$set':{'geocode.latitude': {'$toDouble':'$geocode.latitude' }}} ])

# %%
# Check that the coordinates are now numbers
    
[i for i in establishment_list.find({}, ['geocode.longitude', 'geocode.latitude'])]
# Out:
# [{'_id': ObjectId('6443670612dee6403fbe155b'),
#   'geocode': {'longitude': 1.196408, 'latitude': 51.086058}},
#  {'_id': ObjectId('6443670612dee6403fbe155c'),
#   'geocode': {'longitude': 1.194762, 'latitude': 51.085797}},
#  {'_id': ObjectId('6443670612dee6403fbe1561'),
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('6443670612dee6403fbe1562'),
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('6443670612dee6403fbe1563'),
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('6443670612dee6403fbe1564'),
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('6443670612dee6403fbe1565'),
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('6443670612dee6403fbe1566'),
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('6443670612dee6403fbe1567'),
# ...
